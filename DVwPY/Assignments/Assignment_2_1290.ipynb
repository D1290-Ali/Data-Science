# %% [markdown]
# <a href="https://colab.research.google.com/github/D1290-Ali/Data-Science/blob/main/DVwPY/Assignments/Assignment_2_1290.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
kill = pd.read_csv('/content/sample_data/PoliceKillingsUS (2).csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill.shape
# Out:
# (2535, 14)

# %%
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill["manner_of_death"].unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %%
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
sns.boxplot(x="gender", y="age", data=kill, hue="manner_of_death");

# %%
# with seaborn

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x="gender", y="age", data=kill, hue="manner_of_death");

# %%
# with seaborn

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
city_freq = kill["city"].value_counts().head(12)
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
city_freq = 
city_freq

# %%
kill.city.values
# Out:
# array(['Shelton', 'Aloha', 'Wichita', ..., 'Melba', 'Oshkosh', 'Brooklyn'],
#       dtype=object)

# %%
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(kill.city, kill.city.index, data= kill, order=city_freq.index)
ax.set_xticklabels(city_freq.index, rotation=45)
ax.set_title("Most dangerous cities",color="b", size=14);

# %%
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(city_freq.index, city_freq.values, data= kill)
ax.set_xticklabels(city_freq.index, rotation=45)
ax.set_title("Most dangerous cities",color="b", size=14)
# Out:
# Text(0.5, 1.0, 'Most dangerous cities')

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = 
ax.
ax.

# %%
city_freq.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Oklahoma City', 'Tucson'],
#       dtype='object')

# %%
kill.city.value_counts().index[:12]
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Oklahoma City', 'Tucson'],
#       dtype='object')

# %%
pd.value_counts(kill.city).iloc[:12].index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Oklahoma City', 'Tucson'],
#       dtype='object')

# %%
fig, ax = fig, ax =plt.subplots(figsize=(8,5))
sns.countplot(kill.city, order=city_freq.index)
ax.set_xticklabels(kill.city, rotation=45)
ax.set_title("Most dangerous cities",color="b", size=14);

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_freq = kill["state"].value_counts().head(20)
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
kill.state.index
# Out:
# RangeIndex(start=0, stop=2535, step=1)

# %%
city_freq.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Oklahoma City', 'Tucson'],
#       dtype='object')

# %%
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(state_freq.index, state_freq.values, data= kill)
ax.set_xticklabels(state_freq.index, rotation=45)
ax.set_title("Most dangerous states",color="b", size=14);

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = 
ax.
ax.

# %%
fig, ax = fig, ax =plt.subplots(figsize=(8,5))
sns.countplot(kill.state, order=state_freq.index)
ax.set_xticklabels(kill.state, rotation=45)
ax.set_title("Most dangerous cities",color="b", size=14);

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
illness = kill.signs_of_mental_illness.value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
illness = 
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
sns.countplot("signs_of_mental_illness", data= kill)

# %%
# with seaborn

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
threads_freq = kill.threat_level.value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
sns.countplot("threat_level", data= kill)

# %%
# with seaborn

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
flee_freq = kill.flee.value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
sns.countplot("flee", data= kill)

# %%
# with seaborn
